# %%
import torchvision
import torch
from torch.utils.data.dataloader import DataLoader
from torch.utils.tensorboard import SummaryWriter
import torch.nn as nn
import torch.nn.functional as F

# %%
class My_NN(nn.Module):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
    
    def forward(self,input):
        return input+1

net=My_NN()
x=torch.tensor(1.)
output=net(x)
print(output)
# Out:
# tensor(2.)

# %%
input1=torch.tensor([[9,9,9],[8,8,8],[7,7,7]])
kernel1=torch.tensor([[2,2],[1,1]])
input1=torch.unsqueeze(torch.unsqueeze(input1,0),0)
kernel1=torch.unsqueeze(torch.unsqueeze(kernel1,0),0)
F.conv2d(input1,kernel1,stride=1,padding='valid')
# Out:
# tensor([[[[52, 52],
#           [46, 46]]]])
