# %% [markdown]
# Dataset获取数据，为其提供label
# Dataloader为网络提供不同的数据形式

# %%
import torch
from PIL import Image
from torch.utils.data import Dataset
# help(Dataset)

# %%
img_path = "hymenoptera_data\\train\\ants\\0013035.jpg"
img=Image.open(img_path)

# %%
print(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=768x512 at 0x1D9E4FB0580>

# %%
import os
dir_path="hymenoptera_data\\train\\ants"
img_path_list = os.listdir(dir_path)
print(img_path_list)
# Out:
# ['0013035.jpg', '1030023514_aad5c608f9.jpg', '1095476100_3906d8afde.jpg', '1099452230_d1949d3250.jpg', '116570827_e9c126745d.jpg', '1225872729_6f0856588f.jpg', '1262877379_64fcada201.jpg', '1269756697_0bce92cdab.jpg', '1286984635_5119e80de1.jpg', '132478121_2a430adea2.jpg', '1360291657_dc248c5eea.jpg', '1368913450_e146e2fb6d.jpg', '1473187633_63ccaacea6.jpg', '148715752_302c84f5a4.jpg', '1489674356_09d48dde0a.jpg', '149244013_c529578289.jpg', '150801003_3390b73135.jpg', '150801171_cd86f17ed8.jpg', '154124431_65460430f2.jpg', '162603798_40b51f1654.jpg', '1660097129_384bf54490.jpg', '167890289_dd5ba923f3.jpg', '1693954099_46d4c20605.jpg', '175998972.jpg', '178538489_bec7649292.jpg', '1804095607_0341701e1c.jpg', '1808777855_2a895621d7.jpg', '188552436_605cc9b36b.jpg', '1917341202_d00a7f9af5.jpg', '1924473702_daa9aacdbe.jpg', '196057951_63bf063b92.jpg', '196757565_326437f5fe.jpg', '201558278_fe4caecc76.jpg', '201790779_527f4c0168.jpg', '2019439677_2db655d361.jpg', '207947948_3ab29d7207.j
# ...

# %%
class My_Data(Dataset):
    
    def __init__(self,root_dir,label_dir):
        self.root_dir=root_dir
        self.label_dir=label_dir
        self.path = os.path.join(self.root_dir,self.label_dir)
        self.img_path = os.listdir(self.path)

    def __getitem__(self, index):
        img_name = self.img_path[index]
        img_item_path=os.path.join(self.path,img_name)
        img=Image.open(img_item_path)
        label=self.label_dir
        return img,label
    def __len__(self):
        return len(self.img_path)

# %%
root_dir="hymenoptera_data\\train"
ants_label_dir="ants"
ants_dataset =My_Data(root_dir,ants_label_dir)
bees_label_dir="bees"
bees_dataset =My_Data(root_dir,bees_label_dir)
train_dataset=ants_dataset+bees_dataset

# %% [markdown]
# ***

# %%
from torch.utils.tensorboard import SummaryWriter

# %%
# python=3.8&tensorboard=2.12
writer=SummaryWriter("logs")
# writer.add_image()
# for i in range(100):
#     writer.add_scalar(tag="y=x",scalar_value=i,global_step=i)

# %%
import numpy as np
Image_array=np.array(img)
print(Image_array.shape)
# Out:
# (512, 768, 3)

# %%
# writer.add_image(tag="test",global_step=1,img_tensor=Image_array,dataformats="HWC")

# %% [markdown]
# ***

# %%
from torchvision import transforms
test_totensor=transforms.ToTensor()
tensor_img = test_totensor(pic=img)

# %% [markdown]
# ***

# %%
# resize_img=transforms.Resize(size=[512,512])(tensor_img)
# print(resize_img)
# writer=SummaryWriter("logs")

# writer.add_image(tag="tets_resize",img_tensor=resize_img)

# %%
test_compose=transforms.Compose([transforms.Resize(size=(10,10)),transforms.ToTensor()])(img=img)
print(test_compose.shape)
writer.add_image(tag="tets_resize",img_tensor=test_compose)
# Out:
# torch.Size([3, 10, 10])
